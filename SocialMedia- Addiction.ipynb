# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel(r'C:\Users\Aswini\Downloads\Students Social Media Addiction.xlsx')
df.head(5)
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
df.shape
# Out:
# (705, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# Avg_Daily_Usag                  0
# dtype: int64

# %%
total=len(df)
print(total)
# Out:
# 705

# %%
average_usage=df['Avg_Daily_Usage_Hours'].mean()
print(f"Average daily social media usage time: {average_usage:.2f} hours")
# Out:
# Average daily social media usage time: 4.92 hours

# %%
average_sleepinghours=df['Sleep_Hours_Per_Night'].mean()
print(f"Average daily sleeping time: {average_sleepinghours:.2f} hours ")
# Out:
# Average daily sleeping time: 6.87 hours

# %%
average_mentalhealthscore=df['Mental_Health_Score'].mean()
print(f"Average mental Health Score of Students:{average_mentalhealthscore:.2f}")
# Out:
# Average mental Health Score of Students:6.23

# %% [markdown]
# ## average_addictedpercentage=df['Addicted_Score'].mean()
# print(f"Average addicted percentage of students:{average_addictedpercentage}")

# %%
Single_students=df[df['Relationship_Status']=='Single']
average_usageofsingle=Single_students['Avg_Daily_Usage_Hours'].mean()
print(f"Average daily social media usage time of single students: {average_usageofsingle:.2f} hours")
# Out:
# Average daily social media usage time of single students: 4.93 hours

# %%
HavingRelationship_students=df[df['Relationship_Status']=='In Relationship']

average_usagehavingrelationship=HavingRelationship_students['Avg_Daily_Usage_Hours'].mean()
print(f"Average daily social media usage time of having relationship students: {average_usagehavingrelationship:.2f} hours")
# Out:
# Average daily social media usage time of having relationship students: 4.93 hours

# %%
sns.barplot(data=df,x='Country',y='Avg_Daily_Usage_Hours')
plt.title('Daily Social Media Usage by Country')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1a64ed35a08d> in <module>
#       1 avg_usage_by_level = df.groupby('Academic_Level')['Avg_Daily_Usage_Hours'].mean().sort_values()
# ----> 2 avg_usage_by_level.plot(kind='bar', color='skyblue', edgecolor='black')
#       3 plt.title('Average Daily Social Media Usage by Academic Level')
#       4 plt.xlabel('Academic Level')
#       5 plt.ylabel('Average Hours')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4893d13463ae> in <module>
#       7 avg_usage_by_country = avg_usage_by_country.round()
#       8 plt.figure()
# ----> 9 avg_usage_by_country.plot(kind='pie', labels=avg_usage_by_country.index)
#      10 plt.title('Rounded Average Daily Social Media Usage by Country')
#      11 plt.xlabel('Country')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
print(type(avg_usage_by_country))
print(avg_usage_by_country.head())
# Out:
# <class 'pandas.core.series.Series'>
# Country
# UAE               7.0
# USA               7.0
# Peru              6.0
# Costa Rica        6.0
# Czech Republic    6.0
# Name: Avg_Daily_Usage_Hours, dtype: float64

# %%
import matplotlib.pyplot as plt


values = df.groupby('Country')['Avg_Daily_Usage_Hours'].mean().round()
categories =values.index 
plt.bar(categories, values, color='skyblue')
plt.title('Bar Chart Example')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()

# %%
sns.barplot(data=df,x='Academic_Level',y='Avg_Daily_Usage_Hours',hue='Gender')
plt.title('Daily Social Media Usage by Academic_Level')
plt.show()

# %%
sns.barplot(data=df,x='Gender',y='Avg_Daily_Usage_Hours')
plt.title('Daily Social Media Usage by Gender')
plt.show()

# %%
sns.barplot(data=df,x='Relationship_Status',y='Avg_Daily_Usage_Hours',hue='Gender')
plt.title('Daily Social Media Usage by Relationship_Status ')
plt.show()

# %%
sns.barplot(data=df,x='Most_Used_Platform',y='Avg_Daily_Usage_Hours',hue='Gender')
plt.title('Daily Social Media Usage by Most_Used_Platform  ')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Most_Used_Platform',y='Addicted_Score',hue='Gender')
plt.title('Addicted_Score by Most_Used_Platform  ')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Relationship_Status',y='Addicted_Score',hue='Gender')
plt.title('Addicted_Score by Relationship_Status')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Academic_Level',y='Addicted_Score',hue='Gender')
plt.title('Addicted_Score by Academic_Level')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Most_Used_Platform',y='Mental_Health_Score',hue='Gender')
plt.title('Mental_Health_Score  by Most_Used_Platform  ')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Relationship_Status',y='Mental_Health_Score',hue='Gender')
plt.title('Mental_Health_ScoreRelationship_Status')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Academic_Level',y='Mental_Health_Score',hue='Gender')
plt.title('Mental_Health_Score by Academic_Level')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='',y='Conflicts_Over_Social_Media',hue='Gender')
plt.title('Conflicts_Over_Social_Media by Most_Used_Platform  ')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Relationship_Status',y='Conflicts_Over_Social_Media',hue='Gender')
plt.title('Conflicts_Over_Social_Media by Relationship_Status')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Academic_Level',y='Conflicts_Over_Social_Media',hue='Gender')
plt.title('Conflicts_Over_Social_Media by Academic_Level')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Academic_Level',y='Sleep_Hours_Per_Night',hue='Gender')
plt.title('Sleep_Hours_Per_Night by Academic_Level')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Relationship_Status',y='Sleep_Hours_Per_Night',hue='Gender')
9plt.title('Sleep_Hours_Per_Night by Relationship_Status')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Most_Used_Platform',y='Sleep_Hours_Per_Night',hue='Gender')
plt.title('Sleep_Hours_Per_Night by Most_Used_Platform')
plt.figure(figsize=(30,30))
plt.show()

# %%
values = df.groupby('Country')['Avg_Daily_Usage_Hours'].mean().round()
categories =values.index 
plt.pie(values,labels=values.index)
plt.title('Daily Social Media Usage by Country')
plt.show()

# %%
numerical_cols=['Avg_Daily_Usage_Hours','Sleep_Hours_Per_Night','Conflicts_Over_Social_Media','Addicted_Score','Age']
correlation_matrix=df[numerical_cols].corr()
plt.figure(figsize=(12,12))
sns.heatmap(correlation_matrix,annot=True,cmap='crest',fmt='0.2f')
plt.show()

# %%
numerical_cols=['Avg_Daily_Usage_Hours','Sleep_Hours_Per_Night','Conflicts_Over_Social_Media','Addicted_Score','Age']
for i,cols in enumerate(numerical_cols):
    plt.figure(figsize=(15,15))
    plt.subplot(4,3,i+1)
    sns.histplot(df[cols],kde=True)
    plt.title(cols)
    plt.show()

# %%
numerical_cols=['Avg_Daily_Usage_Hours','Sleep_Hours_Per_Night','Conflicts_Over_Social_Media','Addicted_Score','Age']
for i,cols in enumerate(numerical_cols):
        plt.figure(figsize=(15,15))
        plt.figure(figsize=(8, 4))
        sns.distplot(df[cols],kde=False) 
        plt.title(f'Histogram of {cols} count')
        plt.xlabel(cols)
        plt.ylabel("Count")
        plt.show()
# Out:
# C:\Users\Aswini\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """

# %%
sns.barplot(data=df,x='Age',y='Sleep_Hours_Per_Night',hue='Gender')
plt.title('Sleep_Hours_Per_Night Age')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Age',y='Avg_Daily_Usage_Hours',hue='Gender')
plt.title('Avg_Daily_Usage_Hours by Age')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Age',y='Conflicts_Over_Social_Media',hue='Gender')
plt.title('Conflicts_Over_Social_Media by Age')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.barplot(data=df,x='Age',y='Addicted_Score',hue='Gender')
plt.title('Addicted_Score by Age')
plt.figure(figsize=(30,30))
plt.show()

# %%
sns.scatterplot(data=df, x='Avg_Daily_Usage_Hours', y='Mental_Health_Score')
plt.title('Clusters: Usage vs Mental Health')
plt.show()

# %%
sns.scatterplot(data=df, x='Avg_Daily_Usage_Hours', y='Addicted_Score')
plt.title('Clusters: Usage vs Addicted_Score ')
plt.show()

# %%
sns.scatterplot(data=df, x='Avg_Daily_Usage_Hours', y='Conflicts_Over_Social_Media')
plt.title('Clusters: Usage vs Conflicts_Over_Social_Media')
plt.show()

# %%
sns.scatterplot(data=df, x='Avg_Daily_Usage_Hours', y='Sleep_Hours_Per_Night')
plt.title('Clusters: Usage vs Conflicts_Over_Social_Media')
plt.show()

# %%
sns.barplot(data=df,x='Country',y='Avg_Daily_Usage_Hours',hue='Gender')
plt.title('Sleep_Hours_Per_Night by Most_Used_Platform')
plt.figure()
plt.show()
